# %%
import pandas as pd

# %%
train_people = pd.read_csv('train_people.csv', encoding='EUC-KR')

# %%
train_people.head()
# Out:
#       사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0  202309  1호선  동대문           606            32         10733          1973
# 1  202309  1호선  동묘앞           153             1          2841          1084
# 2  202309  1호선  서울역           596            34          8298          9361
# 3  202309  1호선   시청            55             3          2238          4729
# 4  202309  1호선  신설동           366            12          8783          2336
#
#    06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  23시-24시 하차인원  00시-01시 승차인원  \
# 0          9065          6382         14371  ...          8967           592
# 1          3817          4586          7469  ...          4019            94
# 2         12634         51377         39681  ...         13731          2144
# 3          3924         22886          7976  ...          4323           280
# 4          9456          8139         21484  ...          9270           319
#
# ...

# %%
train_people_september = train_people[train_people['사용월'] >= 202309]

# %%
train_people_september
# Out:
#         사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0    202309  1호선  동대문           606            32         10733          1973
# 1    202309  1호선  동묘앞           153             1          2841          1084
# 2    202309  1호선  서울역           596            34          8298          9361
# 3    202309  1호선   시청            55             3          2238          4729
# 4    202309  1호선  신설동           366            12          8783          2336
# ..      ...  ...  ...           ...           ...           ...           ...
# 611  202309  중앙선   원덕            96             3           314             4
# 612  202309  중앙선   중랑           263            11          6776           572
# 613  202309  중앙선   지평             0             0             0             0
# 614  202309  중앙선   팔당             1             0           271           170
# 615  202309  중앙선   회기          1132             8         12012          4209
#
# ...

# %%
train_people_september_2 = train_people_september[train_people_september['호선명'] == '2호선']
train_people_september_2
# Out:
#        사용월  호선명            지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 10  202309  2호선              강남           127             8          8402
# 11  202309  2호선      강변(동서울터미널)            24             1          8434
# 12  202309  2호선            건대입구           319            10         15855
# 13  202309  2호선      교대(법원.검찰청)            17             3          2380
# 14  202309  2호선         구로디지털단지           461            33         36681
# 15  202309  2호선        구의(광진구청)            81             5         13571
# 16  202309  2호선        낙성대(강감찬)            11             0         11256
# 17  202309  2호선              당산            23             3          6488
# 18  202309  2호선        대림(구로구청)           729            37         31186
# 19  202309  2호선             도림천             2             0           388
# 20  202309  2호선  동대문역사문화공원(DDP)           216             7          4582
# 21  202309  2호선              뚝섬            12             1          3204
# ...

# %%
# Out:
#               사용월  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 사용월           NaN           NaN           NaN           NaN           NaN
# 04시-05시 승차인원  NaN      1.000000      0.561361      0.572302      0.150412
# 04시-05시 하차인원  NaN      0.561361      1.000000      0.853598      0.336932
# 05시-06시 승차인원  NaN      0.572302      0.853598      1.000000      0.312431
# 05시-06시 하차인원  NaN      0.150412      0.336932      0.312431      1.000000
# 06시-07시 승차인원  NaN      0.492098      0.630096      0.909242      0.375980
# 06시-07시 하차인원  NaN      0.030955      0.094558      0.087195      0.867678
# 07시-08시 승차인원  NaN      0.497572      0.574054      0.878735      0.309376
# 07시-08시 하차인원  NaN     -0.012563      0.086909     -0.004295      0.792068
# 08시-09시 승차인원  NaN      0.422188      0.525369      0.850110      0.307357
# 08시-09시 하차인원  NaN     -0.013376      0.079781     -0.034846      0.719705
# 09시-10시 승차인원  NaN      0.426559      0.526537      0.829587      0.391281
# ...
